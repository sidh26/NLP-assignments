# %% [markdown]
# <a href="https://colab.research.google.com/github/sidh26/NLP-assignments/blob/master/homework/Spacy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy
import pandas as pd

# %%
data = pd.read_json("http://snap.stanford.edu/data/amazon/productGraph/categoryFiles/reviews_Office_Products_5.json.gz", lines=True)

# %%
nlp = spacy.load("en_core_web_sm")

# %%
def tlpd(data):
    doc = nlp(data['reviewText'])
    tokens = []
    lemmas = []
    tags = []
    dep = []
    nouns = []
    for token in doc:
        tokens.append(token.text)
        lemmas.append(token.lemma_)
        tags.append(token.tag_)
        dep.append(token.dep_)
        if 'nn' in token.tag_.lower():
            nouns.append(token.text)
    return {'text': tokens, 'lemma_': lemmas, 'tag_': tags, 'dependency parser': dep, 'nouns': nouns, 'noun_count': len(nouns)}

# %%
data['spacy'] = data[:1000].apply(tlpd, axis=1)

# %%
data['spacy'].head()
# Out:
# 0    {'text': ['I', 'bought', 'my', 'first', 'HP12C...
# 1    {'text': ['WHY', 'THIS', 'BELATED', 'REVIEW', ...
# 2    {'text': ['I', 'have', 'an', 'HP', '48GX', 'th...
# 3    {'text': ['I', ''ve', 'started', 'doing', 'mor...
# 4    {'text': ['For', 'simple', 'calculations', 'an...
# Name: spacy, dtype: object

# %%
data['spacy'][0]
# Out:
# {'dependency parser': ['nsubj',
#   'ROOT',
#   'poss',
#   'amod',
#   'dobj',
#   'prep',
#   'advmod',
#   'pobj',
#   'cc',
#   'conj',
#   'punct',
#   'cc',
#   'nsubj',
#   'conj',
#   'dobj',
#   'advmod',
#   'prep',
#   'pobj',
#   'advmod',
#   'nsubj',
#   'relcl',
#   'dobj',
#   'mark',
#   'advcl',
#   'punct',
#   '',
#   'nsubj',
#   'ROOT',
#   'prep',
#   'det',
#   'pobj',
#   'aux',
#   'relcl',
#   'dobj',
#   'punct',
#   'cc',
#   'conj',
#   'nsubj',
#   'ccomp',
#   'aux',
#   'xcomp',
#   'prt',
#   'prep',
#   'poss',
#   'pobj',
#   'punct',
#   '',
#   'advmod',
#   'punct',
#   'nsubj',
#   'ROOT',
#   'aux',
#   'xcomp',
#   'prt',
#   'cc',
#   'conj',
#   'det',
#   'compound',
#   'dobj',
#   '',
#   'det',
#   'det',
#   'ROOT',
#   'punct',
#   '',
#   'nsubj',
#   'ROOT',
#   'mark',
#   'amod',
#   'nsubj',
#   'ccomp',
#   'det',
#   'nmod',
#   'nummod',
#   'dobj',
#   'punct',
#   'advmod',
#   'appos',
#   'punct',
#   'prep',
#   'det',
# ...

# %%
data.shape
# Out:
# (53258, 10)
